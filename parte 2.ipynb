# %%
import pandas as pd
df = pd.read_csv("datos_casas_india.csv")

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# ...

# %%
mascara = df["price"] >=10000

df_mayores = df[mascara]
df_mayores
# Out:
#                     house_type   house_size            location   city  \
# 0       1 RK Studio Apartment     400 sq ft             Kalkaji  Delhi
# 1       1 RK Studio Apartment     400 sq ft   Mansarover Garden  Delhi
# 3     3 BHK Independent House   1,020 sq ft          Model Town  Delhi
# 4             2 BHK Apartment     810 sq ft    Sector 13 Rohini  Delhi
# 5             3 BHK Apartment     750 sq ft           DLF Farms  Delhi
# ...                        ...          ...                 ...    ...
# 4995              4 BHK Villa   5,896 sq ft        Sunder Nagar  Delhi
# 4996  5 BHK Independent House   6,521 sq ft        Sunder Nagar  Delhi
# 4997  3 BHK Independent Floor   1,855 sq ft  New Friends Colony  Delhi
# 4998  3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi
# 4999  3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi
#
#        latitude  longitude    price currency  numBathrooms  numBalconies  \
# ...

# %%
menores_10000= df[df["price"]>=10000]
len(menores_10000)
# Out:
# 4827

# %%
df_mayores = df[df["price"]>=10000]

# %%
df_mayores.info()
df_mayores.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4827 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   house_type        4827 non-null   object
#  1   house_size        4827 non-null   object
#  2   location          4827 non-null   object
#  3   city              4827 non-null   object
#  4   latitude          4827 non-null   float64
#  5   longitude         4827 non-null   float64
#  6   price             4827 non-null   int64
#  7   currency          4827 non-null   object
#  8   numBathrooms      4802 non-null   float64
#  9   numBalconies      2701 non-null   float64
#  10  isNegotiable      171 non-null    object
#  11  priceSqFt         0 non-null      float64
#  12  verificationDate  4827 non-null   object
#  13  description       4545 non-null   object
#  14  SecurityDeposit   4827 non-null   object
#  15  Status            4827 non-null   object
# ...

# %%
serie_location = df_mayores["location"]
serie_location
# Out:
# 0                  Kalkaji
# 1        Mansarover Garden
# 3               Model Town
# 4         Sector 13 Rohini
# 5                DLF Farms
#                ...
# 4995          Sunder Nagar
# 4996          Sunder Nagar
# 4997    New Friends Colony
# 4998    New Friends Colony
# 4999    New Friends Colony
# Name: location, Length: 4827, dtype: object
